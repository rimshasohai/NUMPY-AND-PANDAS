# %% [markdown]
# # WORKING ON PANDAS

# %%
import numpy as np
import pandas as pd

# %%
##ISME ARRAYS SAME LENGTH K HONE CHAIYE
dict1={
    "name":['harry','rohan','rimsha','ali'],
    "marks":[2,34,26,67],
    "city":['karachi','lahore','islamabad','japan']
}

# %%
#TO MAKE A DATAFRAME IF DICT 1
df=pd.DataFrame(dict1)

# %%
ser1=df["name"]
ser1
type(ser1)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#      name  marks       city
# 0   harry      2    karachi
# 1   rohan     34     lahore
# 2  rimsha     26  islamabad
# 3     ali     67      japan

# %%
##CONVERT THIS DATAFRAME TO CSV(PUT IT IN EXCEL SHEET)
df.to_csv('friends.csv')

# %%
##to remove index from excel files
df.to_csv('friends.csv',index=False)

# %%
##describe numerical columns(count,mean,std,min,25%,50%,75%,max)
df.describe()
# Out:
#            marks
# count   4.000000
# mean   32.250000
# std    26.862303
# min     2.000000
# 25%    20.000000
# 50%    30.000000
# 75%    42.250000
# max    67.000000

# %%
#FOR READING A CSV FILE
harry = pd.read_csv('friends.csv')

# %%
harry
# Out:
#      name  marks       city
# 0   harry      2    karachi
# 1   rohan     34     lahore
# 2  rimsha     26  islamabad
# 3     ali     67      japan

# %%
#TO ACCESS A COLUMN
harry['marks']
# Out:
# 0     2
# 1    34
# 2    26
# 3    67
# Name: marks, dtype: int64

# %%
#TO ACCESS THE MARKS OF HARRY AT ZEROTH INDEX
harry['marks'][0]
# Out:
# 2

# %%
#TO CHANGE THE INDEX OF WHOLE DATAFRAME
#ROW KO ACCESS KRNI K LIYE INDEX HOTI H
#COLUMN KO ACCESS KRNI KI LIYE COLUMN K NAME HOTA H
harry.index =['first','second','third','fourth']

# %%
harry
# Out:
#           name  marks       city
# first    harry      2    karachi
# second   rohan     34     lahore
# third   rimsha     26  islamabad
# fourth     ali     67      japan

# %%
##change the marks of first student at zeroth index
harry['marks'][0]=50
# Out:
# <ipython-input-15-2864870b00a4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   harry['marks'][0]=50

# %%
harry
# Out:
#           name  marks       city
# first    harry     50    karachi
# second   rohan     34     lahore
# third   rimsha     26  islamabad
# fourth     ali     67      japan

# %%
#GENERATE SERIES OF NUMBERS FROM 0 TO 33
ser =pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.973144
# 1     0.554918
# 2     0.367915
# 3     0.374497
# 4     0.382382
# 5     0.410376
# 6     0.382069
# 7     0.548688
# 8     0.619874
# 9     0.082590
# 10    0.732540
# 11    0.781696
# 12    0.412762
# 13    0.502674
# 14    0.626608
# 15    0.979357
# 16    0.600734
# 17    0.810112
# 18    0.491921
# 19    0.705882
# 20    0.949867
# 21    0.761949
# 22    0.838268
# 23    0.482546
# 24    0.488199
# 25    0.666565
# 26    0.840192
# 27    0.021573
# 28    0.004301
# 29    0.247950
# 30    0.000114
# 31    0.030092
# 32    0.084009
# 33    0.094009
# dtype: float64

# %%
#to tell the type of the variable
type(ser)
# Out:
# pandas.core.series.Series

# %%
#to create a dataframe with 334 rows and 5 columns and arange take 334 rows
#create dataframe with random numbers
newdf = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0
# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0       654  0.941404  0.726713  0.940208  0.487525
# 1  0.395596  0.939048  0.873318  0.748115  0.536608

# %%
##JO COLUMNS HOGI ISME A,B,C,D,E ADD HOJAI G AS HEADINGS
newdf.columns = list("ABCDE")

# %%
newdf
# Out:
#             A         B         C         D         E
# 0         654  0.941404  0.726713  0.940208  0.487525
# 1    0.395596  0.939048  0.873318  0.748115  0.536608
# 2       harry  0.347555  0.322687  0.331630  0.347400
# 3    0.056028  0.982066  0.529154  0.036822  0.501869
# 4    0.141838  0.558399  0.074074  0.024605  0.408551
# ..        ...       ...       ...       ...       ...
# 329  0.092975  0.014599  0.552725  0.251261  0.748025
# 330  0.293763  0.535196  0.511770  0.051057  0.986992
# 331   0.73855  0.645376  0.850518  0.220374  0.734928
# 332  0.156863  0.209857  0.046680  0.756975  0.617677
# 333  0.874402  0.556067  0.638921  0.951558  0.730477
#
# [334 rows x 5 columns]

# %%
##newdf k 0th row or 0th column me 654 set hoga
newdf.loc[0,'A'] = 6599

# %%
newdf
# Out:
#             A         B         C         D         E
# 0        6599  0.941404  0.726713  0.940208  0.487525
# 1    0.395596  0.939048  0.873318  0.748115  0.536608
# 2       harry  0.347555  0.322687  0.331630  0.347400
# 3    0.056028  0.982066  0.529154  0.036822  0.501869
# 4    0.141838  0.558399  0.074074  0.024605  0.408551
# ..        ...       ...       ...       ...       ...
# 329  0.092975  0.014599  0.552725  0.251261  0.748025
# 330  0.293763  0.535196  0.511770  0.051057  0.986992
# 331   0.73855  0.645376  0.850518  0.220374  0.734928
# 332  0.156863  0.209857  0.046680  0.756975  0.617677
# 333  0.874402  0.556067  0.638921  0.951558  0.730477
#
# [334 rows x 5 columns]

# %%
#ZERO COLUMN DATAFRAME ME NHI TH TO ISNE NEW COLUMN ADD KRDEYA DATAFRAME ME
newdf.loc[0,0] = 6599

# %%
newdf
# Out:
#             A         B         C         D         E       0
# 0        6599  0.941404  0.726713  0.940208  0.487525  6599.0
# 1    0.395596  0.939048  0.873318  0.748115  0.536608     NaN
# 2       harry  0.347555  0.322687  0.331630  0.347400     NaN
# 3    0.056028  0.982066  0.529154  0.036822  0.501869     NaN
# 4    0.141838  0.558399  0.074074  0.024605  0.408551     NaN
# ..        ...       ...       ...       ...       ...     ...
# 329  0.092975  0.014599  0.552725  0.251261  0.748025     NaN
# 330  0.293763  0.535196  0.511770  0.051057  0.986992     NaN
# 331   0.73855  0.645376  0.850518  0.220374  0.734928     NaN
# 332  0.156863  0.209857  0.046680  0.756975  0.617677     NaN
# 333  0.874402  0.556067  0.638921  0.951558  0.730477     NaN
#
# [334 rows x 6 columns]

# %%
#REMOVE NUMBER FROM ROW
newdf.drop(0)

#REMOVE NUMBER FROM COLUMN
newdf.drop(0,axis=1)
# Out:
#             A         B         C         D         E
# 0        6599  0.941404  0.726713  0.940208  0.487525
# 1    0.395596  0.939048  0.873318  0.748115  0.536608
# 2       harry  0.347555  0.322687  0.331630  0.347400
# 3    0.056028  0.982066  0.529154  0.036822  0.501869
# 4    0.141838  0.558399  0.074074  0.024605  0.408551
# ..        ...       ...       ...       ...       ...
# 329  0.092975  0.014599  0.552725  0.251261  0.748025
# 330  0.293763  0.535196  0.511770  0.051057  0.986992
# 331   0.73855  0.645376  0.850518  0.220374  0.734928
# 332  0.156863  0.209857  0.046680  0.756975  0.617677
# 333  0.874402  0.556067  0.638921  0.951558  0.730477
#
# [334 rows x 5 columns]

# %%
#saare rows dedega or C,D column dega bus
newdf.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.726713  0.940208
# 1    0.873318  0.748115
# 2    0.322687  0.331630
# 3    0.529154  0.036822
# 4    0.074074  0.024605
# ..        ...       ...
# 329  0.552725  0.251261
# 330  0.511770  0.051057
# 331  0.850518  0.220374
# 332  0.046680  0.756975
# 333  0.638921  0.951558
#
# [334 rows x 2 columns]

# %%
#[1:2] rows ki liye or [:] saare columns dega
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E   0
# 1  0.395596  0.939048  0.873318  0.748115  0.536608 NaN
# 2     harry  0.347555  0.322687  0.331630  0.347400 NaN

# %%
##JO COLUMN C K JIN ROWS ME VALUES 0.3 SE LESS H WO SHOW HOJAI G
##DONO CONDITIONS TRUE HONI CHAIYE
newdf.loc[(newdf['C']<0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D         E   0
# 17   0.970869  0.990289  0.224735  0.132671  0.098349 NaN
# 26   0.929209  0.833446  0.232955  0.164866  0.392907 NaN
# 31   0.684191  0.746091  0.127314  0.856099  0.098059 NaN
# 32   0.171865  0.607616  0.176067  0.320469  0.068461 NaN
# 34   0.462255  0.214360  0.223397  0.450797  0.439894 NaN
# ..        ...       ...       ...       ...       ...  ..
# 319  0.057664  0.294563  0.257474  0.220035  0.566880 NaN
# 320  0.239749  0.249822  0.140546  0.408037  0.255533 NaN
# 324  0.538902  0.257136  0.194161  0.921731  0.167188 NaN
# 325  0.528879  0.848366  0.229720  0.820883  0.989979 NaN
# 326  0.016719  0.133245  0.229936  0.268800  0.841572 NaN
#
# [70 rows x 6 columns]

# %% [markdown]
# # ILOC
# ##illoc is used for accesing columns values

# %%
##ILOC COLUMN K PEHLI VALUE KO DEGA
newdf.iloc[0,5]
# Out:
# 6599.0

# %%
newdf
# Out:
#             A         B         C         D         E       0
# 0        6599  0.941404  0.726713  0.940208  0.487525  6599.0
# 1    0.395596  0.939048  0.873318  0.748115  0.536608     NaN
# 2       harry  0.347555  0.322687  0.331630  0.347400     NaN
# 3    0.056028  0.982066  0.529154  0.036822  0.501869     NaN
# 4    0.141838  0.558399  0.074074  0.024605  0.408551     NaN
# ..        ...       ...       ...       ...       ...     ...
# 329  0.092975  0.014599  0.552725  0.251261  0.748025     NaN
# 330  0.293763  0.535196  0.511770  0.051057  0.986992     NaN
# 331   0.73855  0.645376  0.850518  0.220374  0.734928     NaN
# 332  0.156863  0.209857  0.046680  0.756975  0.617677     NaN
# 333  0.874402  0.556067  0.638921  0.951558  0.730477     NaN
#
# [334 rows x 6 columns]

# %%
##[0,1] for accessing row and [1,2] for accessing column
newdf.iloc[[0,1],[1,2]]
# Out:
#           B         C
# 0  0.941404  0.726713
# 1  0.939048  0.873318

# %%
newdf.head(3)
# Out:
#           A         B         C         D         E       0
# 0      6599  0.941404  0.726713  0.940208  0.487525  6599.0
# 1  0.395596  0.939048  0.873318  0.748115  0.536608     NaN
# 2     harry  0.347555  0.322687  0.331630  0.347400     NaN

# %%
#FOR DROPPING ROWS
newdf.drop([0],axis=0)
# Out:
#             A         B         C         D         E   0
# 1    0.395596  0.939048  0.873318  0.748115  0.536608 NaN
# 2       harry  0.347555  0.322687  0.331630  0.347400 NaN
# 3    0.056028  0.982066  0.529154  0.036822  0.501869 NaN
# 4    0.141838  0.558399  0.074074  0.024605  0.408551 NaN
# 5    0.632061  0.802064  0.335564  0.958449  0.703966 NaN
# ..        ...       ...       ...       ...       ...  ..
# 329  0.092975  0.014599  0.552725  0.251261  0.748025 NaN
# 330  0.293763  0.535196  0.511770  0.051057  0.986992 NaN
# 331   0.73855  0.645376  0.850518  0.220374  0.734928 NaN
# 332  0.156863  0.209857  0.046680  0.756975  0.617677 NaN
# 333  0.874402  0.556067  0.638921  0.951558  0.730477 NaN
#
# [333 rows x 6 columns]

# %%
#FOR DROPPING COLUMNS
##COLUMNS KI LIYE AXIS 1 DE GI OR ROWS KI LIYE AXIS ZERO DEGI
newdf.drop(['A'],axis=1)
# Out:
#             B         C         D         E       0
# 0    0.941404  0.726713  0.940208  0.487525  6599.0
# 1    0.939048  0.873318  0.748115  0.536608     NaN
# 2    0.347555  0.322687  0.331630  0.347400     NaN
# 3    0.982066  0.529154  0.036822  0.501869     NaN
# 4    0.558399  0.074074  0.024605  0.408551     NaN
# ..        ...       ...       ...       ...     ...
# 329  0.014599  0.552725  0.251261  0.748025     NaN
# 330  0.535196  0.511770  0.051057  0.986992     NaN
# 331  0.645376  0.850518  0.220374  0.734928     NaN
# 332  0.209857  0.046680  0.756975  0.617677     NaN
# 333  0.556067  0.638921  0.951558  0.730477     NaN
#
# [334 rows x 5 columns]

# %%
#ORIGINAL COLUMN ME CHANGE AI GA
newdf.drop(['C'],axis=1,inplace=True)

# %%
newdf
# Out:
#             A         B         D         E       0
# 0        6599  0.941404  0.940208  0.487525  6599.0
# 1    0.395596  0.939048  0.748115  0.536608     NaN
# 2       harry  0.347555  0.331630  0.347400     NaN
# 3    0.056028  0.982066  0.036822  0.501869     NaN
# 4    0.141838  0.558399  0.024605  0.408551     NaN
# ..        ...       ...       ...       ...     ...
# 329  0.092975  0.014599  0.251261  0.748025     NaN
# 330  0.293763  0.535196  0.051057  0.986992     NaN
# 331   0.73855  0.645376  0.220374  0.734928     NaN
# 332  0.156863  0.209857  0.756975  0.617677     NaN
# 333  0.874402  0.556067  0.951558  0.730477     NaN
#
# [334 rows x 5 columns]

# %%
##REMOVE ROWS FROM 1 TO 5
newdf.drop([0,3] ,axis=0 ,inplace=True)

# %%
newdf
# Out:
#             A         B         D         E   0
# 1    0.395596  0.939048  0.748115  0.536608 NaN
# 2       harry  0.347555  0.331630  0.347400 NaN
# 4    0.141838  0.558399  0.024605  0.408551 NaN
# 5    0.632061  0.802064  0.958449  0.703966 NaN
# 6     0.04231  0.154545  0.687679  0.713391 NaN
# ..        ...       ...       ...       ...  ..
# 329  0.092975  0.014599  0.251261  0.748025 NaN
# 330  0.293763  0.535196  0.051057  0.986992 NaN
# 331   0.73855  0.645376  0.220374  0.734928 NaN
# 332  0.156863  0.209857  0.756975  0.617677 NaN
# 333  0.874402  0.556067  0.951558  0.730477 NaN
#
# [332 rows x 5 columns]

# %%
#WAPIS 0 SE LEKI 3 TK ROWS K VALUES CHAIYE SO WE DO THIS
#jb index k column nhi chaiye hota to drop=True or inplace=True likhte h
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#             A         B         D         E   0
# 0    0.395596  0.939048  0.748115  0.536608 NaN
# 1       harry  0.347555  0.331630  0.347400 NaN
# 2    0.141838  0.558399  0.024605  0.408551 NaN
# 3    0.632061  0.802064  0.958449  0.703966 NaN
# 4     0.04231  0.154545  0.687679  0.713391 NaN
# ..        ...       ...       ...       ...  ..
# 327  0.092975  0.014599  0.251261  0.748025 NaN
# 328  0.293763  0.535196  0.051057  0.986992 NaN
# 329   0.73855  0.645376  0.220374  0.734928 NaN
# 330  0.156863  0.209857  0.756975  0.617677 NaN
# 331  0.874402  0.556067  0.951558  0.730477 NaN
#
# [332 rows x 5 columns]

# %%
newdf['E'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: E, Length: 332, dtype: bool

# %%
newdf.loc[:,['B']]=789

# %%
newdf
# Out:
#             A    B         D         E   0
# 0    0.395596  789  0.748115  0.536608 NaN
# 1       harry  789  0.331630  0.347400 NaN
# 2    0.141838  789  0.024605  0.408551 NaN
# 3    0.632061  789  0.958449  0.703966 NaN
# 4     0.04231  789  0.687679  0.713391 NaN
# ..        ...  ...       ...       ...  ..
# 327  0.092975  789  0.251261  0.748025 NaN
# 328  0.293763  789  0.051057  0.986992 NaN
# 329   0.73855  789  0.220374  0.734928 NaN
# 330  0.156863  789  0.756975  0.617677 NaN
# 331  0.874402  789  0.951558  0.730477 NaN
#
# [332 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A    B         D         E   0
# 0  0.395596  789  0.748115  0.536608 NaN
# 1     harry  789  0.331630  0.347400 NaN
# 2  0.141838  789  0.024605  0.408551 NaN
# 3  0.632061  789  0.958449  0.703966 NaN
# 4   0.04231  789  0.687679  0.713391 NaN

# %%
#for making dataframe
#for inserting null values(np.nan)
df = pd.DataFrame([1,2,3,np.nan,5])

# %%
df
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  3.0
# 3  NaN
# 4  5.0

# %%
#jaha bh Na arha hoga isko drop krde g
df.dropna()
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  3.0
# 4  5.0

# %%
df.shape
# Out:
# (5, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      float64
# dtypes: float64(1)
# memory usage: 168.0 bytes

# %%
df.describe()
# Out:
#               0
# count  4.000000
# mean   2.750000
# std    1.707825
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.500000
# max    5.000000

# %%
#counting me NA k include nhi krna
df[0].value_counts(dropna=False)
# Out:
# 3.0    1
# 2.0    1
# 5.0    1
# NaN    1
# 1.0    1
# Name: 0, dtype: int64

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "Location":['US','INDIA','BRZAIL','RUSSIA','UK','FRANCE','SPAIN','ITALY','TURKEY','GERMANY'],
    "Cases":[28833039,11079979,10517232,4246079,4170519,3736016,3188553,2907825,2693164,2444169],
    "Deaths":[517204,156938,254263,86122,122705,86332,69142,97507,28503,70601],
    "Recovered":[np.nan,10763451,9386440,3811797,np.nan,np.nan,np.nan,2398352,2565723,2242767],
    "Status":[np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
}

# %%
df=pd.DataFrame(dict1)

# %%
ser22= df['Location']

# %%
ser22
# Out:
# 0         US
# 1      INDIA
# 2     BRZAIL
# 3     RUSSIA
# 4         UK
# 5     FRANCE
# 6      SPAIN
# 7      ITALY
# 8     TURKEY
# 9    GERMANY
# Name: Location, dtype: object

# %%
type(ser22)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#   Location     Cases  Deaths   Recovered  Status
# 0       US  28833039  517204         NaN     NaN
# 1    INDIA  11079979  156938  10763451.0     NaN
# 2   BRZAIL  10517232  254263   9386440.0     NaN
# 3   RUSSIA   4246079   86122   3811797.0     NaN
# 4       UK   4170519  122705         NaN     NaN
# 5   FRANCE   3736016   86332         NaN     NaN
# 6    SPAIN   3188553   69142         NaN     NaN
# 7    ITALY   2907825   97507   2398352.0     NaN
# 8   TURKEY   2693164   28503   2565723.0     NaN
# 9  GERMANY   2444169   70601   2242767.0     NaN

# %%
seri= df.loc[(df['Cases']< 3000000)]

# %%
seri
# Out:
#   Location    Cases  Deaths  Recovered  Status
# 7    ITALY  2907825   97507  2398352.0     NaN
# 8   TURKEY  2693164   28503  2565723.0     NaN
# 9  GERMANY  2444169   70601  2242767.0     NaN

# %%
df.loc[[7,8,9],['Status']]="LOW"

# %%
df
# Out:
#   Location     Cases  Deaths   Recovered Status
# 0       US  28833039  517204         NaN    NaN
# 1    INDIA  11079979  156938  10763451.0    NaN
# 2   BRZAIL  10517232  254263   9386440.0    NaN
# 3   RUSSIA   4246079   86122   3811797.0    NaN
# 4       UK   4170519  122705         NaN    NaN
# 5   FRANCE   3736016   86332         NaN    NaN
# 6    SPAIN   3188553   69142         NaN    NaN
# 7    ITALY   2907825   97507   2398352.0    LOW
# 8   TURKEY   2693164   28503   2565723.0    LOW
# 9  GERMANY   2444169   70601   2242767.0    LOW

# %%
seri1= df.loc[(df['Cases']> 3000000) & (df['Cases']< 4000000)]

# %%
seri1
# Out:
#   Location    Cases  Deaths  Recovered Status
# 5   FRANCE  3736016   86332        NaN    NaN
# 6    SPAIN  3188553   69142        NaN    NaN

# %%
df.loc[[5,6],['Status']]="MEDIUM"

# %%
df
# Out:
#   Location     Cases  Deaths   Recovered  Status
# 0       US  28833039  517204         NaN     NaN
# 1    INDIA  11079979  156938  10763451.0     NaN
# 2   BRZAIL  10517232  254263   9386440.0     NaN
# 3   RUSSIA   4246079   86122   3811797.0     NaN
# 4       UK   4170519  122705         NaN     NaN
# 5   FRANCE   3736016   86332         NaN  MEDIUM
# 6    SPAIN   3188553   69142         NaN  MEDIUM
# 7    ITALY   2907825   97507   2398352.0     LOW
# 8   TURKEY   2693164   28503   2565723.0     LOW
# 9  GERMANY   2444169   70601   2242767.0     LOW

# %%
df.loc[[0,1,2,3,4],['Status']]="HIGH"

# %%
df
# Out:
#   Location     Cases  Deaths   Recovered  Status
# 0       US  28833039  517204         NaN    HIGH
# 1    INDIA  11079979  156938  10763451.0    HIGH
# 2   BRZAIL  10517232  254263   9386440.0    HIGH
# 3   RUSSIA   4246079   86122   3811797.0    HIGH
# 4       UK   4170519  122705         NaN    HIGH
# 5   FRANCE   3736016   86332         NaN  MEDIUM
# 6    SPAIN   3188553   69142         NaN  MEDIUM
# 7    ITALY   2907825   97507   2398352.0     LOW
# 8   TURKEY   2693164   28503   2565723.0     LOW
# 9  GERMANY   2444169   70601   2242767.0     LOW

# %%
np=df.sort_values("Deaths")
np
np.index =['first','second','third','fourth','fifth','sixth','seventh','eighth','nineth','tenth']

# %%
np
# Out:
#         Location     Cases  Deaths   Recovered  Status
# first     TURKEY   2693164   28503   2565723.0     LOW
# second     SPAIN   3188553   69142         NaN  MEDIUM
# third    GERMANY   2444169   70601   2242767.0     LOW
# fourth    RUSSIA   4246079   86122   3811797.0    HIGH
# fifth     FRANCE   3736016   86332         NaN  MEDIUM
# sixth      ITALY   2907825   97507   2398352.0     LOW
# seventh       UK   4170519  122705         NaN    HIGH
# eighth     INDIA  11079979  156938  10763451.0    HIGH
# nineth    BRZAIL  10517232  254263   9386440.0    HIGH
# tenth         US  28833039  517204         NaN    HIGH

# %%
df
# Out:
#   Location     Cases  Deaths   Recovered  Status
# 0       US  28833039  517204         NaN     NaN
# 1    INDIA  11079979  156938  10763451.0     NaN
# 2   BRZAIL  10517232  254263   9386440.0     NaN
# 3   RUSSIA   4246079   86122   3811797.0     NaN
# 4       UK   4170519  122705         NaN     NaN
# 5   FRANCE   3736016   86332         NaN     NaN
# 6    SPAIN   3188553   69142         NaN     NaN
# 7    ITALY   2907825   97507   2398352.0     NaN
# 8   TURKEY   2693164   28503   2565723.0     NaN
# 9  GERMANY   2444169   70601   2242767.0     NaN

# %%
se=df.drop([0,4,5,6],axis=0)
se
# Out:
#   Location     Cases  Deaths   Recovered  Status
# 1    INDIA  11079979  156938  10763451.0     NaN
# 2   BRZAIL  10517232  254263   9386440.0     NaN
# 3   RUSSIA   4246079   86122   3811797.0     NaN
# 7    ITALY   2907825   97507   2398352.0     NaN
# 8   TURKEY   2693164   28503   2565723.0     NaN
# 9  GERMANY   2444169   70601   2242767.0     NaN

# %%
meaner=df['Recovered'].mean()
#meaner
#df['Recovered'].fillna(meaner,inplace=True)
#df
moder=df['Recovered'].median()
print('The mean value is:',meaner)
print('The median value is:',moder)
df['Recovered'].fillna(moder,inplace=True)
df
# Out:
# The mean value is: 5194755.0
# The median value is: 5194755.0
#   Location     Cases  Deaths   Recovered  Status
# 0       US  28833039  517204   5194755.0     NaN
# 1    INDIA  11079979  156938  10763451.0     NaN
# 2   BRZAIL  10517232  254263   9386440.0     NaN
# 3   RUSSIA   4246079   86122   3811797.0     NaN
# 4       UK   4170519  122705   5194755.0     NaN
# 5   FRANCE   3736016   86332   5194755.0     NaN
# 6    SPAIN   3188553   69142   5194755.0     NaN
# 7    ITALY   2907825   97507   2398352.0     NaN
# 8   TURKEY   2693164   28503   2565723.0     NaN
# 9  GERMANY   2444169   70601   2242767.0     NaN

# %%
df['Recovered'].isnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: Recovered, dtype: bool

# %%
##STATISTICAL METHODS
df.describe()
# Out:
#               Cases         Deaths     Recovered
# count  1.000000e+01      10.000000  1.000000e+01
# mean   7.381658e+06  148931.700000  5.194755e+06
# std    8.172197e+06  143366.103826  2.866261e+06
# min    2.444169e+06   28503.000000  2.242767e+06
# 25%    2.978007e+06   74481.250000  2.877242e+06
# 50%    3.953268e+06   91919.500000  5.194755e+06
# 75%    8.949444e+06  148379.750000  5.194755e+06
# max    2.883304e+07  517204.000000  1.076345e+07

# %%
df.mean()
# Out:
# Cases        7381657.5
# Deaths        148931.7
# Recovered    5194755.0
# dtype: float64

# %%
df.count()
# Out:
# Location     10
# Cases        10
# Deaths       10
# Recovered    10
# Status       10
# dtype: int64

# %%
df.max()
# Out:
# Location             US
# Cases          28833039
# Deaths           517204
# Recovered    10763451.0
# Status           MEDIUM
# dtype: object

# %%
df.min()
# Out:
# Location        BRZAIL
# Cases          2444169
# Deaths           28503
# Recovered    2242767.0
# Status            HIGH
# dtype: object

# %%
df.median()
# Out:
# Cases        3953267.5
# Deaths         91919.5
# Recovered    5194755.0
# dtype: float64

# %%
df['Cases'].sum()
# Out:
# 73816575

# %%
df['Deaths'].sum()
# Out:
# 1489317

# %%
df['Cases'].mean()
# Out:
# 7381657.5

# %%
df['Cases'].median()
# Out:
# 3953267.5

# %%
df['Deaths'].mean()
# Out:
# 148931.7

# %%
df['Deaths'].median()
# Out:
# 91919.5

# %%
df['Deaths'].var()
# Out:
# 20553839726.23333

# %%
df['Cases'].var()
# Out:
# 66784801015163.61
